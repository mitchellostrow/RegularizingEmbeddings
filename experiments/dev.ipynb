# %%
import torch

import sys
sys.path.append("..")

import hydra
from hydra.core.global_hydra import GlobalHydra
import matplotlib.pyplot as plt

# %%
# Initialize Hydra if it hasn't been already
if not GlobalHydra().is_initialized():
    hydra.initialize(config_path="../conf", version_base=None)

# Now load the config
config = hydra.compose(config_name="config")
config
# Out:
# {'training': {'wandb': {'project': 'sequence_model', 'name': '${now:%Y-%m-%d_%H-%M-%S}'}, 'training': {'max_epochs': 100, 'patience': 50}, 'data': {'__target__': 'src.lightning.data.SequenceDataModule', 'batch_size': 32, 'num_workers': 4, 'pin_memory': True}, 'optimizer': {'_target_': 'torch.optim.AdamW', 'lr': 0.001, 'weight_decay': 0.0}, 'scheduler': {'_target_': 'torch.optim.lr_scheduler.ReduceLROnPlateau', 'mode': 'min', 'factor': 0.1, 'patience': 5}, 'criterion': {'_target_': 'torch.nn.MSELoss'}, 'regularization_lambda': 0.001, 'paths': {'output_dir': 'checkpoints'}}, 'model': {'_target_': 'RegularizingEmbeddings.models.lru.LRUMinimal', 'input_dim': None, 'd_model': 256, 'd_state': 64, 'mlp_hidden': 1024, 'siso': False, 'rmin': 0.8, 'rmax': 0.99, 'dropout': 0.1}, 'data': {'flow': {'_target_': 'RegularizingEmbeddings.dysts_sim.flows.Lorenz', 'random_state': 42, 'dt': None}, 'trajectory_params': {'n_periods': 12, 'method': 'Radau', 'resample': True, 'pts_per_period': 200, 'return_times': True, 'standardize': False, 'noise': 0.0, 'num_ics': 20, 'new_ic_mode': 'reference', 'traj_offset_sd': 0.01, 'verbose': True}, 'postprocessing': {'obs_noise': 0, 'dims_to_observe': 'all', 'filter_data': False, 'low_pass': 10, 'high_pass': None}, 'train_test_params': {'seq_length': 25, 'seq_spacing': 1, 'train_percent': 0.7, 'test_percent': 0.1, 'split_by': 'trajectory', 'dtype': 'torch.FloatTensor', 'verbose': True, 'delay_embedding_params': {'observed_indices': 'all', 'n_delays': 1, 'delay_spacing': 1}}}, 'logger': 'wandb'}

# %%
from RegularizingEmbeddings.lightning.train import train

train(config)
# Out:
# 2025-03-06 10:36:52.499 | INFO     | RegularizingEmbeddings.lightning.train:train:45 - Training with config: {'training': {'wandb': {'project': 'sequence_model', 'name': '${now:%Y-%m-%d_%H-%M-%S}'}, 'training': {'max_epochs': 100, 'patience': 50}, 'data': {'__target__': 'src.lightning.data.SequenceDataModule', 'batch_size': 32, 'num_workers': 4, 'pin_memory': True}, 'optimizer': {'_target_': 'torch.optim.AdamW', 'lr': 0.001, 'weight_decay': 0.0}, 'scheduler': {'_target_': 'torch.optim.lr_scheduler.ReduceLROnPlateau', 'mode': 'min', 'factor': 0.1, 'patience': 5}, 'criterion': {'_target_': 'torch.nn.MSELoss'}, 'regularization_lambda': 0.001, 'paths': {'output_dir': 'checkpoints'}}, 'model': {'_target_': 'RegularizingEmbeddings.models.lru.LRUMinimal', 'input_dim': None, 'd_model': 256, 'd_state': 64, 'mlp_hidden': 1024, 'siso': False, 'rmin': 0.8, 'rmax': 0.99, 'dropout': 0.1}, 'data': {'flow': {'_target_': 'RegularizingEmbeddings.dysts_sim.flows.Lorenz', 'random_state': 42, 'dt': None}, 'trajectory_params': {'n_periods': 12, 'method': 'Radau', 'resample': True, 'pts_per_period': 200, 'return_times': True, 'standardize': False, 'noise': 0.0, 'num_ics': 20, 'new_ic_mode': 'reference', 'traj_offset_sd': 0.01, 'verbose': True}, 'postprocessing': {'obs_noise': 0, 'dims_to_observe': 'all', 'filter_data': False, 'low_pass': 10, 'high_pass': None}, 'train_test_params': {'seq_length': 25, 'seq_spacing': 1, 'train_percent': 0.7, 'test_percent': 0.1, 'split_by': 'trajectory', 'dtype': 'torch.FloatTensor', 'verbose': True, 'delay_embedding_params': {'observed_indices': 'all', 'n_delays': 1, 'delay_spacing': 1}}}, 'logger': 'wandb'}
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# 2025-03-06 10:36:52.533 | INFO     | RegularizingEmbeddings.lightning.train:train:78 - Trainer initialized. Generating data
# 2025-03-06 10:36:54.065 | INFO     | RegularizingEmbeddings.lightning.train:train:84 - Data generated. Creating train and test sets
# ---------------------------------------------------------------------------
# UnsupportedValueType                      Traceback (most recent call last)
# Cell In[10], line 3
#       1 from RegularizingEmbeddings.lightning.train import train
# ----> 3 train(config)
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\hydra\main.py:83, in main.<locals>.main_decorator.<locals>.decorated_main(cfg_passthrough)
#      80 @functools.wraps(task_function)
#      81 def decorated_main(cfg_passthrough: Optional[DictConfig] = None) -> Any:
#      82     if cfg_passthrough is not None:
# ---> 83         return task_function(cfg_passthrough)
#      84     else:
#      85         args_parser = get_args_parser()
#
# File c:\Users\feder\Documents\github\RegularizingEmbeddings\experiments\..\RegularizingEmbeddings\lightning\train.py:87, in train(config)
#      84 logger.info(f"Data generated. Creating train and test sets")
#      86 # update dt in config
# ---> 87 config.data.flow.dt = dt
#      88 config.regularization.dt = dt
#      90 config.model.input_dim = values.shape[-1]
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\dictconfig.py:337, in DictConfig.__setattr__(self, key, value)
#     335 except Exception as e:
#     336     if isinstance(e, OmegaConfBaseException) and e._initialized:
# --> 337         raise e
#     338     self._format_and_raise(key=key, value=value, cause=e)
#     339     assert False
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\dictconfig.py:334, in DictConfig.__setattr__(self, key, value)
#     327 """
#     328 Allow assigning attributes to DictConfig
#     329 :param key:
#     330 :param value:
#     331 :return:
#     332 """
#     333 try:
# --> 334     self.__set_impl(key, value)
#     335 except Exception as e:
#     336     if isinstance(e, OmegaConfBaseException) and e._initialized:
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\dictconfig.py:318, in DictConfig.__set_impl(self, key, value)
#     316 def __set_impl(self, key: DictKeyType, value: Any) -> None:
#     317     key = self._validate_and_normalize_key(key)
# --> 318     self._set_item_impl(key, value)
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\basecontainer.py:620, in BaseContainer._set_item_impl(self, key, value)
#     618         assign(key, value)
#     619 else:
# --> 620     self._wrap_value_and_set(key, value, target_type_hint)
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\basecontainer.py:636, in BaseContainer._wrap_value_and_set(self, key, val, type_hint)
#     628     wrapped = _maybe_wrap(
#     629         ref_type=ref_type,
#     630         key=key,
#    (...)
#     633         parent=self,
#     634     )
#     635 except ValidationError as e:
# --> 636     self._format_and_raise(key=key, value=val, cause=e)
#     637 self.__dict__["_content"][key] = wrapped
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\base.py:231, in Node._format_and_raise(self, key, value, cause, msg, type_override)
#     223 def _format_and_raise(
#     224     self,
#     225     key: Any,
#    (...)
#     229     type_override: Any = None,
#     230 ) -> None:
# --> 231     format_and_raise(
#     232         node=self,
#     233         key=key,
#     234         value=value,
#     235         msg=str(cause) if msg is None else msg,
#     236         cause=cause,
#     237         type_override=type_override,
#     238     )
#     239     assert False
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\_utils.py:899, in format_and_raise(node, key, value, msg, cause, type_override)
#     896     ex.ref_type = ref_type
#     897     ex.ref_type_str = ref_type_str
# --> 899 _raise(ex, cause)
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\_utils.py:797, in _raise(ex, cause)
#     795 else:
#     796     ex.__cause__ = None
# --> 797 raise ex.with_traceback(sys.exc_info()[2])
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\basecontainer.py:628, in BaseContainer._wrap_value_and_set(self, key, val, type_hint)
#     625 is_optional, ref_type = _resolve_optional(type_hint)
#     627 try:
# --> 628     wrapped = _maybe_wrap(
#     629         ref_type=ref_type,
#     630         key=key,
#     631         value=val,
#     632         is_optional=is_optional,
#     633         parent=self,
#     634     )
#     635 except ValidationError as e:
#     636     self._format_and_raise(key=key, value=val, cause=e)
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\omegaconf.py:1105, in _maybe_wrap(ref_type, key, value, is_optional, parent)
#    1103     return value
#    1104 else:
# -> 1105     return _node_wrap(
#    1106         ref_type=ref_type,
#    1107         parent=parent,
#    1108         is_optional=is_optional,
#    1109         value=value,
#    1110         key=key,
#    1111     )
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\omegaconf.py:1045, in _node_wrap(parent, is_optional, value, key, ref_type)
#    1037     node = UnionNode(
#    1038         content=value,
#    1039         ref_type=ref_type,
#    (...)
#    1042         parent=parent,
#    1043     )
#    1044 elif ref_type == Any or ref_type is None:
# -> 1045     node = AnyNode(value=value, key=key, parent=parent)
#    1046 elif isinstance(ref_type, type) and issubclass(ref_type, Enum):
#    1047     node = EnumNode(
#    1048         enum_type=ref_type,
#    1049         value=value,
#    (...)
#    1052         is_optional=is_optional,
#    1053     )
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\nodes.py:135, in AnyNode.__init__(self, value, key, parent, flags)
#     128 def __init__(
#     129     self,
#     130     value: Any = None,
#    (...)
#     133     flags: Optional[Dict[str, bool]] = None,
#     134 ):
# --> 135     super().__init__(
#     136         parent=parent,
#     137         value=value,
#     138         metadata=Metadata(
#     139             ref_type=Any, object_type=None, key=key, optional=True, flags=flags
#     140         ),
#     141     )
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\nodes.py:29, in ValueNode.__init__(self, parent, value, metadata)
#      27 super().__init__(parent=parent, metadata=metadata)
#      28 with read_write(self):
# ---> 29     self._set_value(value)
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\nodes.py:46, in ValueNode._set_value(self, value, flags)
#      44     self._val = value
#      45 else:
# ---> 46     self._val = self.validate_and_convert(value)
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\nodes.py:76, in ValueNode.validate_and_convert(self, value)
#      74     return value
#      75 else:
# ---> 76     return self._validate_and_convert_impl(value)
#
# File c:\Users\feder\.conda\envs\omen\lib\site-packages\omegaconf\nodes.py:154, in AnyNode._validate_and_convert_impl(self, value)
#     150 if self._get_flag(
#     151     "allow_objects"
#     152 ) is not True and not is_primitive_type_annotation(value):
#     153     t = get_type_of(value)
# --> 154     raise UnsupportedValueType(
#     155         f"Value '{t.__name__}' is not a supported primitive type"
#     156     )
#     157 return value
#
# UnsupportedValueType: Value 'float64' is not a supported primitive type
#     full_key: data.flow.dt
#     object_type=dict
